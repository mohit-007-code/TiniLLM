# %%
import torch
import torch.nn as nn

# %%
class Embedding(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()

        self.embedding_matrix = nn.Parameter(
            torch.randn(vocab_size, embedding_dim)
        )

# %%
vocab_size = 10000
embedding_dim = 512

embedding = Embedding(vocab_size, embedding_dim)

print("Embedding Matrix: ")
print(embedding.embedding_matrix)

print("Shape: ")
print(embedding.embedding_matrix.shape)
# Out:
# Embedding Matrix:
# Parameter containing:
# tensor([[ 0.3751,  0.1351, -2.4881,  ..., -1.0108, -1.1724,  1.7282],
#         [ 0.2017, -1.7961, -0.9905,  ...,  0.5829, -0.9877, -1.6349],
#         [ 0.9851,  1.7206,  0.8150,  ...,  0.7041, -1.1343, -0.0530],
#         ...,
#         [-1.0653,  3.5603,  0.2215,  ..., -0.1009,  0.7926, -0.6339],
#         [ 2.5979, -0.1846,  0.3860,  ..., -1.0368, -0.4872,  0.3928],
#         [-1.6257, -1.5426,  0.8470,  ..., -0.4455,  0.4396, -0.1775]],
#        requires_grad=True)
# Shape:
# torch.Size([10000, 512])
